# %% [markdown]
# # Machine Learning Foundation
#
# ## Course 5, Part c: Backpropagation DEMO

# %% [markdown]
# ## Overview
# In this exercise we will use backpropagation to train a multi-layer perceptron (with a single hidden layer).  We will experiment with different patterns and see how quickly or slowly the weights converge.  We will see the impact and interplay of different parameters such as learning rate, number of iterations, and number of data points.

# %%
#Setup
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In this exercise, we will prepare code to create a multi-layer perceptron with a single hidden layer (with 4 nodes) and train it via back-propagation.  We will take the following steps:
#
# 1. Initialize the weights to random values between -1 and 1
# 1. Perform the feed-forward computation
# 1. Compute the loss function
# 1. Calculate the gradients for all the weights via back-propagation
# 1. Update the weight matrices (using a learning_rate parameter)
# 1. Execute steps 2-5 for a fixed number of iterations
# 1. Plot the accuracies and log loss and observe how they change over time
#
#
# Once the code is running, we can address the following questions:
# - Which patterns was the neural network able to learn quickly and which took longer?
# - What learning rates and numbers of iterations worked well?
# - If you have time, try varying the size of the hidden layer and experiment with different activation functions (e.g. ReLu)

# %%
## This code below generates two x values and a y value according to different patterns
## It also creates a "bias" term (a vector of 1s)
## The goal is then to learn the mapping from x to y using a neural network via back-propagation

num_obs = 500
x_mat_1 = np.random.uniform(-1,1,size = (num_obs,2))
x_mat_bias = np.ones((num_obs,1))
x_mat_full = np.concatenate( (x_mat_1,x_mat_bias), axis=1)

# PICK ONE PATTERN BELOW and comment out the rest.

# # Circle pattern
# y = (np.sqrt(x_mat_full[:,0]**2 + x_mat_full[:,1]**2)<.75).astype(int)

# # Diamond Pattern
y = ((np.abs(x_mat_full[:,0]) + np.abs(x_mat_full[:,1]))<1).astype(int)

# # Centered square
# y = ((np.maximum(np.abs(x_mat_full[:,0]), np.abs(x_mat_full[:,1])))<.5).astype(int)

# # Thick Right Angle pattern
# y = (((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))<.5) & ((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))>-.5)).astype(int)

# # Thin right angle pattern
# y = (((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))<.5) & ((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))>0)).astype(int)


print('shape of x_mat_full is {}'.format(x_mat_full.shape))
print('shape of y is {}'.format(y.shape))

fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x_mat_full[y==1, 0],x_mat_full[y==1, 1], 'ro', label='class 1', color='darkslateblue')
ax.plot(x_mat_full[y==0, 0],x_mat_full[y==0, 1], 'bx', label='class 0', color='chocolate')
# ax.grid(True)
ax.legend(loc='best')
ax.axis('equal');
# Out:
# shape of x_mat_full is (500, 3)
# shape of y is (500,)

# %% [markdown]
# Here are some helper functions

# %%
def sigmoid(x):
    """
    Sigmoid function
    """
    return 1.0 / (1.0 + np.exp(-x))


def loss_fn(y_true, y_pred, eps=1e-16):
    """
    Loss function we would like to optimize (minimize)
    We are using Logarithmic Loss
    http://scikit-learn.org/stable/modules/model_evaluation.html#log-loss
    """
    y_pred = np.maximum(y_pred,eps)
    y_pred = np.minimum(y_pred,(1-eps))
    return -(np.sum(y_true * np.log(y_pred)) + np.sum((1-y_true)*np.log(1-y_pred)))/len(y_true)


def forward_pass(W1, W2):
    """
    Does a forward computation of the neural network
    Takes the input `x_mat` (global variable) and produces the output `y_pred`
    Also produces the gradient of the log loss function
    """
    global x_mat
    global y
    global num_
    # First, compute the new predictions `y_pred`
    z_2 = np.dot(x_mat, W_1)
    a_2 = sigmoid(z_2)
    z_3 = np.dot(a_2, W_2)
    y_pred = sigmoid(z_3).reshape((len(x_mat),))
    # Now compute the gradient
    J_z_3_grad = -y + y_pred
    J_W_2_grad = np.dot(J_z_3_grad, a_2)
    a_2_z_2_grad = sigmoid(z_2)*(1-sigmoid(z_2))
    J_W_1_grad = (np.dot((J_z_3_grad).reshape(-1,1), W_2.reshape(-1,1).T)*a_2_z_2_grad).T.dot(x_mat).T
    gradient = (J_W_1_grad, J_W_2_grad)
    
    # return
    return y_pred, gradient


def plot_loss_accuracy(loss_vals, accuracies):
    fig = plt.figure(figsize=(16, 8))
    fig.suptitle('Log Loss and Accuracy over iterations')
    
    ax = fig.add_subplot(1, 2, 1)
    ax.plot(loss_vals)
    ax.grid(True)
    ax.set(xlabel='iterations', title='Log Loss')
    
    ax = fig.add_subplot(1, 2, 2)
    ax.plot(accuracies)
    ax.grid(True)
    ax.set(xlabel='iterations', title='Accuracy');

# %%
#### Initialize the network parameters

np.random.seed(1241)

W_1 = np.random.uniform(-1,1,size=(3,4))
W_2 = np.random.uniform(-1,1,size=(4))
num_iter = 100000
learning_rate = .0001
x_mat = x_mat_full


loss_vals, accuracies = [], []
for i in range(num_iter):
    ### Do a forward computation, and get the gradient
    y_pred, (J_W_1_grad, J_W_2_grad) = forward_pass(W_1, W_2)
    
    ## Update the weight matrices
    W_1 = W_1 - learning_rate*J_W_1_grad 
    W_2 = W_2 - learning_rate*J_W_2_grad
    
    ### Compute the loss and accuracy
    curr_loss = loss_fn(y,y_pred)
    loss_vals.append(curr_loss)
    acc = np.sum((y_pred>=.5) == y)/num_obs
    accuracies.append(acc)

    ## Print the loss and accuracy for every 200th iteration
    if((i%200) == 0):
        print('iteration {}, log loss is {:.4f}, accuracy is {}'.format(
            i, curr_loss, acc
        ))
plot_loss_accuracy(loss_vals, accuracies)
# Out:
# iteration 0, log loss is 0.7966, accuracy is 0.512
# iteration 200, log loss is 0.6887, accuracy is 0.526
# iteration 400, log loss is 0.6881, accuracy is 0.556
# iteration 600, log loss is 0.6877, accuracy is 0.556
# iteration 800, log loss is 0.6873, accuracy is 0.562
# iteration 1000, log loss is 0.6868, accuracy is 0.558
# iteration 1200, log loss is 0.6863, accuracy is 0.562
# iteration 1400, log loss is 0.6858, accuracy is 0.564
# iteration 1600, log loss is 0.6851, accuracy is 0.564
# iteration 1800, log loss is 0.6845, accuracy is 0.566
# iteration 2000, log loss is 0.6837, accuracy is 0.568
# iteration 2200, log loss is 0.6828, accuracy is 0.57
# iteration 2400, log loss is 0.6818, accuracy is 0.576
# iteration 2600, log loss is 0.6807, accuracy is 0.58
# iteration 2800, log loss is 0.6794, accuracy is 0.588
# iteration 3000, log loss is 0.6779, accuracy is 0.6
# iteration 3200, log loss is 0.6762, accuracy is 0.608
# iteration 3400, log loss is 0.6743, accuracy is 0.614
# iteration 3600, log loss is 0.6720, accuracy is 0.626
# iteration 3800, log loss is 0.6694, accuracy is 0.638
# iteration 4000, log loss is 0.6665, accuracy is 0.648
# iteration 4200, log loss is 0.6631, accuracy is 0.658
# iteration 4400, log loss is 0.6592, accuracy is 0.684
# iteration 4600, log loss is 0.6549, accuracy is 0.7
# iteration 4800, log loss is 0.6500, accuracy is 0.708
# iteration 5000, log loss is 0.6446, accuracy is 0.712
# iteration 5200, log loss is 0.6386, accuracy is 0.724
# iteration 5400, log loss is 0.6321, accuracy is 0.728
# iteration 5600, log loss is 0.6250, accuracy is 0.754
# iteration 5800, log loss is 0.6175, accuracy is 0.744
# iteration 6000, log loss is 0.6096, accuracy is 0.75
# iteration 6200, log loss is 0.6014, accuracy is 0.744
# iteration 6400, log loss is 0.5932, accuracy is 0.752
# iteration 6600, log loss is 0.5850, accuracy is 0.752
# iteration 6800, log loss is 0.5769, accuracy is 0.752
# iteration 7000, log loss is 0.5693, accuracy is 0.744
# iteration 7200, log loss is 0.5620, accuracy is 0.746
# iteration 7400, log loss is 0.5553, accuracy is 0.748
# iteration 7600, log loss is 0.5492, accuracy is 0.748
# iteration 7800, log loss is 0.5436, accuracy is 0.746
# iteration 8000, log loss is 0.5387, accuracy is 0.75
# iteration 8200, log loss is 0.5342, accuracy is 0.748
# iteration 8400, log loss is 0.5303, accuracy is 0.746
# iteration 8600, log loss is 0.5269, accuracy is 0.748
# iteration 8800, log loss is 0.5238, accuracy is 0.748
# iteration 9000, log loss is 0.5211, accuracy is 0.748
# iteration 9200, log loss is 0.5186, accuracy is 0.75
# iteration 9400, log loss is 0.5164, accuracy is 0.75
# iteration 9600, log loss is 0.5143, accuracy is 0.752
# iteration 9800, log loss is 0.5124, accuracy is 0.754
# iteration 10000, log loss is 0.5105, accuracy is 0.756
# iteration 10200, log loss is 0.5087, accuracy is 0.758
# iteration 10400, log loss is 0.5068, accuracy is 0.76
# iteration 10600, log loss is 0.5048, accuracy is 0.758
# iteration 10800, log loss is 0.5027, accuracy is 0.756
# iteration 11000, log loss is 0.5005, accuracy is 0.756
# iteration 11200, log loss is 0.4979, accuracy is 0.756
# iteration 11400, log loss is 0.4950, accuracy is 0.756
# iteration 11600, log loss is 0.4917, accuracy is 0.758
# iteration 11800, log loss is 0.4879, accuracy is 0.76
# iteration 12000, log loss is 0.4835, accuracy is 0.764
# iteration 12200, log loss is 0.4784, accuracy is 0.77
# iteration 12400, log loss is 0.4726, accuracy is 0.774
# iteration 12600, log loss is 0.4660, accuracy is 0.782
# iteration 12800, log loss is 0.4586, accuracy is 0.796
# iteration 13000, log loss is 0.4505, accuracy is 0.808
# iteration 13200, log loss is 0.4418, accuracy is 0.812
# iteration 13400, log loss is 0.4328, accuracy is 0.822
# iteration 13600, log loss is 0.4236, accuracy is 0.832
# iteration 13800, log loss is 0.4145, accuracy is 0.846
# iteration 14000, log loss is 0.4056, accuracy is 0.85
# iteration 14200, log loss is 0.3970, accuracy is 0.86
# iteration 14400, log loss is 0.3888, accuracy is 0.868
# iteration 14600, log loss is 0.3810, accuracy is 0.878
# iteration 14800, log loss is 0.3738, accuracy is 0.872
# iteration 15000, log loss is 0.3670, accuracy is 0.872
# iteration 15200, log loss is 0.3608, accuracy is 0.878
# iteration 15400, log loss is 0.3549, accuracy is 0.882
# iteration 15600, log loss is 0.3495, accuracy is 0.886
# iteration 15800, log loss is 0.3444, accuracy is 0.892
# iteration 16000, log loss is 0.3397, accuracy is 0.892
# iteration 16200, log loss is 0.3353, accuracy is 0.89
# iteration 16400, log loss is 0.3312, accuracy is 0.888
# iteration 16600, log loss is 0.3273, accuracy is 0.892
# iteration 16800, log loss is 0.3236, accuracy is 0.894
# iteration 17000, log loss is 0.3202, accuracy is 0.898
# iteration 17200, log loss is 0.3169, accuracy is 0.898
# iteration 17400, log loss is 0.3137, accuracy is 0.898
# iteration 17600, log loss is 0.3107, accuracy is 0.898
# iteration 17800, log loss is 0.3078, accuracy is 0.9
# iteration 18000, log loss is 0.3050, accuracy is 0.9
# iteration 18200, log loss is 0.3023, accuracy is 0.9
# iteration 18400, log loss is 0.2996, accuracy is 0.9
# iteration 18600, log loss is 0.2971, accuracy is 0.9
# iteration 18800, log loss is 0.2945, accuracy is 0.9
# iteration 19000, log loss is 0.2921, accuracy is 0.902
# iteration 19200, log loss is 0.2896, accuracy is 0.902
# iteration 19400, log loss is 0.2872, accuracy is 0.902
# iteration 19600, log loss is 0.2849, accuracy is 0.904
# iteration 19800, log loss is 0.2825, accuracy is 0.904
# iteration 20000, log loss is 0.2802, accuracy is 0.906
# iteration 20200, log loss is 0.2779, accuracy is 0.91
# iteration 20400, log loss is 0.2756, accuracy is 0.908
# iteration 20600, log loss is 0.2733, accuracy is 0.908
# iteration 20800, log loss is 0.2710, accuracy is 0.91
# iteration 21000, log loss is 0.2688, accuracy is 0.914
# iteration 21200, log loss is 0.2666, accuracy is 0.916
# iteration 21400, log loss is 0.2644, accuracy is 0.916
# iteration 21600, log loss is 0.2623, accuracy is 0.916
# iteration 21800, log loss is 0.2602, accuracy is 0.916
# iteration 22000, log loss is 0.2581, accuracy is 0.916
# iteration 22200, log loss is 0.2561, accuracy is 0.918
# iteration 22400, log loss is 0.2541, accuracy is 0.918
# iteration 22600, log loss is 0.2522, accuracy is 0.92
# iteration 22800, log loss is 0.2502, accuracy is 0.92
# iteration 23000, log loss is 0.2483, accuracy is 0.92
# iteration 23200, log loss is 0.2464, accuracy is 0.92
# iteration 23400, log loss is 0.2445, accuracy is 0.92
# iteration 23600, log loss is 0.2427, accuracy is 0.92
# iteration 23800, log loss is 0.2408, accuracy is 0.922
# iteration 24000, log loss is 0.2389, accuracy is 0.922
# iteration 24200, log loss is 0.2370, accuracy is 0.922
# iteration 24400, log loss is 0.2350, accuracy is 0.922
# iteration 24600, log loss is 0.2331, accuracy is 0.922
# iteration 24800, log loss is 0.2311, accuracy is 0.922
# iteration 25000, log loss is 0.2291, accuracy is 0.924
# iteration 25200, log loss is 0.2271, accuracy is 0.926
# iteration 25400, log loss is 0.2250, accuracy is 0.93
# iteration 25600, log loss is 0.2230, accuracy is 0.93
# iteration 25800, log loss is 0.2210, accuracy is 0.93
# iteration 26000, log loss is 0.2190, accuracy is 0.93
# iteration 26200, log loss is 0.2170, accuracy is 0.934
# iteration 26400, log loss is 0.2151, accuracy is 0.934
# iteration 26600, log loss is 0.2132, accuracy is 0.934
# iteration 26800, log loss is 0.2113, accuracy is 0.934
# iteration 27000, log loss is 0.2095, accuracy is 0.936
# iteration 27200, log loss is 0.2077, accuracy is 0.94
# iteration 27400, log loss is 0.2059, accuracy is 0.94
# iteration 27600, log loss is 0.2043, accuracy is 0.94
# iteration 27800, log loss is 0.2026, accuracy is 0.94
# iteration 28000, log loss is 0.2010, accuracy is 0.94
# iteration 28200, log loss is 0.1995, accuracy is 0.94
# iteration 28400, log loss is 0.1980, accuracy is 0.942
# iteration 28600, log loss is 0.1965, accuracy is 0.942
# iteration 28800, log loss is 0.1951, accuracy is 0.944
# iteration 29000, log loss is 0.1938, accuracy is 0.944
# iteration 29200, log loss is 0.1924, accuracy is 0.946
# iteration 29400, log loss is 0.1912, accuracy is 0.948
# iteration 29600, log loss is 0.1899, accuracy is 0.95
# iteration 29800, log loss is 0.1887, accuracy is 0.95
# iteration 30000, log loss is 0.1875, accuracy is 0.954
# iteration 30200, log loss is 0.1864, accuracy is 0.954
# iteration 30400, log loss is 0.1853, accuracy is 0.954
# iteration 30600, log loss is 0.1842, accuracy is 0.956
# iteration 30800, log loss is 0.1831, accuracy is 0.958
# iteration 31000, log loss is 0.1821, accuracy is 0.958
# iteration 31200, log loss is 0.1811, accuracy is 0.96
# iteration 31400, log loss is 0.1801, accuracy is 0.958
# iteration 31600, log loss is 0.1792, accuracy is 0.96
# iteration 31800, log loss is 0.1783, accuracy is 0.96
# iteration 32000, log loss is 0.1774, accuracy is 0.96
# iteration 32200, log loss is 0.1765, accuracy is 0.96
# iteration 32400, log loss is 0.1757, accuracy is 0.958
# iteration 32600, log loss is 0.1748, accuracy is 0.958
# iteration 32800, log loss is 0.1740, accuracy is 0.958
# iteration 33000, log loss is 0.1732, accuracy is 0.958
# iteration 33200, log loss is 0.1725, accuracy is 0.958
# iteration 33400, log loss is 0.1717, accuracy is 0.958
# iteration 33600, log loss is 0.1710, accuracy is 0.958
# iteration 33800, log loss is 0.1703, accuracy is 0.958
# iteration 34000, log loss is 0.1696, accuracy is 0.958
# iteration 34200, log loss is 0.1689, accuracy is 0.962
# iteration 34400, log loss is 0.1682, accuracy is 0.96
# iteration 34600, log loss is 0.1676, accuracy is 0.96
# iteration 34800, log loss is 0.1669, accuracy is 0.96
# iteration 35000, log loss is 0.1663, accuracy is 0.96
# iteration 35200, log loss is 0.1657, accuracy is 0.96
# iteration 35400, log loss is 0.1651, accuracy is 0.96
# iteration 35600, log loss is 0.1645, accuracy is 0.96
# iteration 35800, log loss is 0.1639, accuracy is 0.96
# iteration 36000, log loss is 0.1633, accuracy is 0.96
# iteration 36200, log loss is 0.1628, accuracy is 0.96
# iteration 36400, log loss is 0.1622, accuracy is 0.96
# iteration 36600, log loss is 0.1617, accuracy is 0.96
# iteration 36800, log loss is 0.1612, accuracy is 0.96
# iteration 37000, log loss is 0.1607, accuracy is 0.96
# iteration 37200, log loss is 0.1602, accuracy is 0.96
# iteration 37400, log loss is 0.1597, accuracy is 0.96
# iteration 37600, log loss is 0.1592, accuracy is 0.958
# iteration 37800, log loss is 0.1587, accuracy is 0.958
# iteration 38000, log loss is 0.1582, accuracy is 0.958
# iteration 38200, log loss is 0.1577, accuracy is 0.958
# iteration 38400, log loss is 0.1573, accuracy is 0.96
# iteration 38600, log loss is 0.1568, accuracy is 0.96
# iteration 38800, log loss is 0.1564, accuracy is 0.96
# iteration 39000, log loss is 0.1560, accuracy is 0.96
# iteration 39200, log loss is 0.1555, accuracy is 0.958
# iteration 39400, log loss is 0.1551, accuracy is 0.956
# iteration 39600, log loss is 0.1547, accuracy is 0.956
# iteration 39800, log loss is 0.1543, accuracy is 0.956
# iteration 40000, log loss is 0.1539, accuracy is 0.956
# iteration 40200, log loss is 0.1535, accuracy is 0.956
# iteration 40400, log loss is 0.1531, accuracy is 0.956
# iteration 40600, log loss is 0.1527, accuracy is 0.956
# iteration 40800, log loss is 0.1524, accuracy is 0.956
# iteration 41000, log loss is 0.1520, accuracy is 0.956
# iteration 41200, log loss is 0.1516, accuracy is 0.956
# iteration 41400, log loss is 0.1512, accuracy is 0.958
# iteration 41600, log loss is 0.1509, accuracy is 0.958
# iteration 41800, log loss is 0.1505, accuracy is 0.958
# iteration 42000, log loss is 0.1502, accuracy is 0.958
# iteration 42200, log loss is 0.1498, accuracy is 0.958
# iteration 42400, log loss is 0.1495, accuracy is 0.958
# iteration 42600, log loss is 0.1492, accuracy is 0.958
# iteration 42800, log loss is 0.1488, accuracy is 0.958
# iteration 43000, log loss is 0.1485, accuracy is 0.958
# iteration 43200, log loss is 0.1482, accuracy is 0.96
# iteration 43400, log loss is 0.1479, accuracy is 0.96
# iteration 43600, log loss is 0.1476, accuracy is 0.96
# iteration 43800, log loss is 0.1472, accuracy is 0.96
# iteration 44000, log loss is 0.1469, accuracy is 0.96
# iteration 44200, log loss is 0.1466, accuracy is 0.96
# iteration 44400, log loss is 0.1463, accuracy is 0.96
# iteration 44600, log loss is 0.1460, accuracy is 0.962
# iteration 44800, log loss is 0.1458, accuracy is 0.962
# iteration 45000, log loss is 0.1455, accuracy is 0.962
# iteration 45200, log loss is 0.1452, accuracy is 0.962
# iteration 45400, log loss is 0.1449, accuracy is 0.962
# iteration 45600, log loss is 0.1446, accuracy is 0.962
# iteration 45800, log loss is 0.1443, accuracy is 0.964
# iteration 46000, log loss is 0.1441, accuracy is 0.964
# iteration 46200, log loss is 0.1438, accuracy is 0.964
# iteration 46400, log loss is 0.1435, accuracy is 0.964
# iteration 46600, log loss is 0.1433, accuracy is 0.964
# iteration 46800, log loss is 0.1430, accuracy is 0.964
# iteration 47000, log loss is 0.1427, accuracy is 0.966
# iteration 47200, log loss is 0.1425, accuracy is 0.966
# iteration 47400, log loss is 0.1422, accuracy is 0.966
# iteration 47600, log loss is 0.1420, accuracy is 0.966
# iteration 47800, log loss is 0.1417, accuracy is 0.966
# iteration 48000, log loss is 0.1415, accuracy is 0.966
# iteration 48200, log loss is 0.1412, accuracy is 0.966
# iteration 48400, log loss is 0.1410, accuracy is 0.966
# iteration 48600, log loss is 0.1407, accuracy is 0.966
# iteration 48800, log loss is 0.1405, accuracy is 0.966
# iteration 49000, log loss is 0.1403, accuracy is 0.966
# iteration 49200, log loss is 0.1400, accuracy is 0.966
# iteration 49400, log loss is 0.1398, accuracy is 0.966
# iteration 49600, log loss is 0.1396, accuracy is 0.966
# iteration 49800, log loss is 0.1394, accuracy is 0.966
# iteration 50000, log loss is 0.1391, accuracy is 0.966
# iteration 50200, log loss is 0.1389, accuracy is 0.966
# iteration 50400, log loss is 0.1387, accuracy is 0.966
# iteration 50600, log loss is 0.1385, accuracy is 0.966
# iteration 50800, log loss is 0.1383, accuracy is 0.966
# iteration 51000, log loss is 0.1380, accuracy is 0.964
# iteration 51200, log loss is 0.1378, accuracy is 0.964
# iteration 51400, log loss is 0.1376, accuracy is 0.964
# iteration 51600, log loss is 0.1374, accuracy is 0.964
# iteration 51800, log loss is 0.1372, accuracy is 0.964
# iteration 52000, log loss is 0.1370, accuracy is 0.964
# iteration 52200, log loss is 0.1368, accuracy is 0.964
# iteration 52400, log loss is 0.1366, accuracy is 0.964
# iteration 52600, log loss is 0.1364, accuracy is 0.964
# iteration 52800, log loss is 0.1362, accuracy is 0.964
# iteration 53000, log loss is 0.1360, accuracy is 0.964
# iteration 53200, log loss is 0.1358, accuracy is 0.964
# iteration 53400, log loss is 0.1356, accuracy is 0.964
# iteration 53600, log loss is 0.1354, accuracy is 0.964
# iteration 53800, log loss is 0.1352, accuracy is 0.964
# iteration 54000, log loss is 0.1350, accuracy is 0.964
# iteration 54200, log loss is 0.1348, accuracy is 0.964
# iteration 54400, log loss is 0.1347, accuracy is 0.964
# iteration 54600, log loss is 0.1345, accuracy is 0.964
# iteration 54800, log loss is 0.1343, accuracy is 0.964
# iteration 55000, log loss is 0.1341, accuracy is 0.964
# iteration 55200, log loss is 0.1339, accuracy is 0.964
# iteration 55400, log loss is 0.1337, accuracy is 0.964
# iteration 55600, log loss is 0.1336, accuracy is 0.964
# iteration 55800, log loss is 0.1334, accuracy is 0.964
# iteration 56000, log loss is 0.1332, accuracy is 0.964
# iteration 56200, log loss is 0.1330, accuracy is 0.964
# iteration 56400, log loss is 0.1329, accuracy is 0.964
# iteration 56600, log loss is 0.1327, accuracy is 0.964
# iteration 56800, log loss is 0.1325, accuracy is 0.964
# iteration 57000, log loss is 0.1324, accuracy is 0.964
# iteration 57200, log loss is 0.1322, accuracy is 0.964
# iteration 57400, log loss is 0.1320, accuracy is 0.964
# iteration 57600, log loss is 0.1319, accuracy is 0.964
# iteration 57800, log loss is 0.1317, accuracy is 0.964
# iteration 58000, log loss is 0.1315, accuracy is 0.964
# iteration 58200, log loss is 0.1314, accuracy is 0.964
# iteration 58400, log loss is 0.1312, accuracy is 0.964
# iteration 58600, log loss is 0.1310, accuracy is 0.964
# iteration 58800, log loss is 0.1309, accuracy is 0.964
# iteration 59000, log loss is 0.1307, accuracy is 0.964
# iteration 59200, log loss is 0.1306, accuracy is 0.964
# iteration 59400, log loss is 0.1304, accuracy is 0.964
# iteration 59600, log loss is 0.1303, accuracy is 0.964
# iteration 59800, log loss is 0.1301, accuracy is 0.964
# iteration 60000, log loss is 0.1299, accuracy is 0.964
# iteration 60200, log loss is 0.1298, accuracy is 0.964
# iteration 60400, log loss is 0.1296, accuracy is 0.964
# iteration 60600, log loss is 0.1295, accuracy is 0.964
# iteration 60800, log loss is 0.1293, accuracy is 0.964
# iteration 61000, log loss is 0.1292, accuracy is 0.964
# iteration 61200, log loss is 0.1291, accuracy is 0.964
# iteration 61400, log loss is 0.1289, accuracy is 0.964
# iteration 61600, log loss is 0.1288, accuracy is 0.964
# iteration 61800, log loss is 0.1286, accuracy is 0.964
# iteration 62000, log loss is 0.1285, accuracy is 0.964
# iteration 62200, log loss is 0.1283, accuracy is 0.964
# iteration 62400, log loss is 0.1282, accuracy is 0.964
# iteration 62600, log loss is 0.1280, accuracy is 0.964
# iteration 62800, log loss is 0.1279, accuracy is 0.964
# iteration 63000, log loss is 0.1278, accuracy is 0.964
# iteration 63200, log loss is 0.1276, accuracy is 0.964
# iteration 63400, log loss is 0.1275, accuracy is 0.964
# iteration 63600, log loss is 0.1274, accuracy is 0.964
# iteration 63800, log loss is 0.1272, accuracy is 0.964
# iteration 64000, log loss is 0.1271, accuracy is 0.964
# iteration 64200, log loss is 0.1269, accuracy is 0.964
# iteration 64400, log loss is 0.1268, accuracy is 0.966
# iteration 64600, log loss is 0.1267, accuracy is 0.966
# iteration 64800, log loss is 0.1265, accuracy is 0.966
# iteration 65000, log loss is 0.1264, accuracy is 0.966
# iteration 65200, log loss is 0.1263, accuracy is 0.966
# iteration 65400, log loss is 0.1262, accuracy is 0.966
# iteration 65600, log loss is 0.1260, accuracy is 0.966
# iteration 65800, log loss is 0.1259, accuracy is 0.968
# iteration 66000, log loss is 0.1258, accuracy is 0.968
# iteration 66200, log loss is 0.1256, accuracy is 0.968
# iteration 66400, log loss is 0.1255, accuracy is 0.968
# iteration 66600, log loss is 0.1254, accuracy is 0.968
# iteration 66800, log loss is 0.1253, accuracy is 0.968
# iteration 67000, log loss is 0.1251, accuracy is 0.968
# iteration 67200, log loss is 0.1250, accuracy is 0.968
# iteration 67400, log loss is 0.1249, accuracy is 0.968
# iteration 67600, log loss is 0.1248, accuracy is 0.968
# iteration 67800, log loss is 0.1247, accuracy is 0.968
# iteration 68000, log loss is 0.1245, accuracy is 0.968
# iteration 68200, log loss is 0.1244, accuracy is 0.968
# iteration 68400, log loss is 0.1243, accuracy is 0.968
# iteration 68600, log loss is 0.1242, accuracy is 0.968
# iteration 68800, log loss is 0.1241, accuracy is 0.968
# iteration 69000, log loss is 0.1239, accuracy is 0.968
# iteration 69200, log loss is 0.1238, accuracy is 0.968
# iteration 69400, log loss is 0.1237, accuracy is 0.968
# iteration 69600, log loss is 0.1236, accuracy is 0.968
# iteration 69800, log loss is 0.1235, accuracy is 0.968
# iteration 70000, log loss is 0.1234, accuracy is 0.968
# iteration 70200, log loss is 0.1232, accuracy is 0.968
# iteration 70400, log loss is 0.1231, accuracy is 0.968
# iteration 70600, log loss is 0.1230, accuracy is 0.968
# iteration 70800, log loss is 0.1229, accuracy is 0.968
# iteration 71000, log loss is 0.1228, accuracy is 0.968
# iteration 71200, log loss is 0.1227, accuracy is 0.968
# iteration 71400, log loss is 0.1226, accuracy is 0.968
# iteration 71600, log loss is 0.1225, accuracy is 0.968
# iteration 71800, log loss is 0.1224, accuracy is 0.968
# iteration 72000, log loss is 0.1222, accuracy is 0.968
# iteration 72200, log loss is 0.1221, accuracy is 0.968
# iteration 72400, log loss is 0.1220, accuracy is 0.968
# iteration 72600, log loss is 0.1219, accuracy is 0.968
# iteration 72800, log loss is 0.1218, accuracy is 0.968
# iteration 73000, log loss is 0.1217, accuracy is 0.968
# iteration 73200, log loss is 0.1216, accuracy is 0.968
# iteration 73400, log loss is 0.1215, accuracy is 0.968
# iteration 73600, log loss is 0.1214, accuracy is 0.968
# iteration 73800, log loss is 0.1213, accuracy is 0.968
# iteration 74000, log loss is 0.1212, accuracy is 0.968
# iteration 74200, log loss is 0.1211, accuracy is 0.968
# iteration 74400, log loss is 0.1210, accuracy is 0.968
# iteration 74600, log loss is 0.1209, accuracy is 0.968
# iteration 74800, log loss is 0.1208, accuracy is 0.968
# iteration 75000, log loss is 0.1207, accuracy is 0.968
# iteration 75200, log loss is 0.1206, accuracy is 0.968
# iteration 75400, log loss is 0.1205, accuracy is 0.968
# iteration 75600, log loss is 0.1204, accuracy is 0.968
# iteration 75800, log loss is 0.1203, accuracy is 0.968
# iteration 76000, log loss is 0.1202, accuracy is 0.968
# iteration 76200, log loss is 0.1201, accuracy is 0.968
# iteration 76400, log loss is 0.1200, accuracy is 0.97
# iteration 76600, log loss is 0.1199, accuracy is 0.97
# iteration 76800, log loss is 0.1198, accuracy is 0.97
# iteration 77000, log loss is 0.1197, accuracy is 0.97
# iteration 77200, log loss is 0.1196, accuracy is 0.97
# iteration 77400, log loss is 0.1195, accuracy is 0.97
# iteration 77600, log loss is 0.1194, accuracy is 0.97
# iteration 77800, log loss is 0.1193, accuracy is 0.97
# iteration 78000, log loss is 0.1192, accuracy is 0.97
# iteration 78200, log loss is 0.1191, accuracy is 0.97
# iteration 78400, log loss is 0.1190, accuracy is 0.97
# iteration 78600, log loss is 0.1189, accuracy is 0.972
# iteration 78800, log loss is 0.1188, accuracy is 0.972
# iteration 79000, log loss is 0.1187, accuracy is 0.972
# iteration 79200, log loss is 0.1186, accuracy is 0.972
# iteration 79400, log loss is 0.1185, accuracy is 0.972
# iteration 79600, log loss is 0.1184, accuracy is 0.972
# iteration 79800, log loss is 0.1183, accuracy is 0.972
# iteration 80000, log loss is 0.1183, accuracy is 0.972
# iteration 80200, log loss is 0.1182, accuracy is 0.972
# iteration 80400, log loss is 0.1181, accuracy is 0.972
# iteration 80600, log loss is 0.1180, accuracy is 0.972
# iteration 80800, log loss is 0.1179, accuracy is 0.972
# iteration 81000, log loss is 0.1178, accuracy is 0.972
# iteration 81200, log loss is 0.1177, accuracy is 0.972
# iteration 81400, log loss is 0.1176, accuracy is 0.972
# iteration 81600, log loss is 0.1175, accuracy is 0.972
# iteration 81800, log loss is 0.1174, accuracy is 0.972
# iteration 82000, log loss is 0.1174, accuracy is 0.972
# iteration 82200, log loss is 0.1173, accuracy is 0.972
# iteration 82400, log loss is 0.1172, accuracy is 0.972
# iteration 82600, log loss is 0.1171, accuracy is 0.972
# iteration 82800, log loss is 0.1170, accuracy is 0.972
# iteration 83000, log loss is 0.1169, accuracy is 0.972
# iteration 83200, log loss is 0.1168, accuracy is 0.972
# iteration 83400, log loss is 0.1167, accuracy is 0.972
# iteration 83600, log loss is 0.1167, accuracy is 0.972
# iteration 83800, log loss is 0.1166, accuracy is 0.972
# iteration 84000, log loss is 0.1165, accuracy is 0.972
# iteration 84200, log loss is 0.1164, accuracy is 0.972
# iteration 84400, log loss is 0.1163, accuracy is 0.972
# iteration 84600, log loss is 0.1162, accuracy is 0.972
# iteration 84800, log loss is 0.1162, accuracy is 0.972
# iteration 85000, log loss is 0.1161, accuracy is 0.972
# iteration 85200, log loss is 0.1160, accuracy is 0.972
# iteration 85400, log loss is 0.1159, accuracy is 0.972
# iteration 85600, log loss is 0.1158, accuracy is 0.972
# iteration 85800, log loss is 0.1157, accuracy is 0.972
# iteration 86000, log loss is 0.1157, accuracy is 0.972
# iteration 86200, log loss is 0.1156, accuracy is 0.972
# iteration 86400, log loss is 0.1155, accuracy is 0.972
# iteration 86600, log loss is 0.1154, accuracy is 0.972
# iteration 86800, log loss is 0.1153, accuracy is 0.972
# iteration 87000, log loss is 0.1153, accuracy is 0.972
# iteration 87200, log loss is 0.1152, accuracy is 0.972
# iteration 87400, log loss is 0.1151, accuracy is 0.972
# iteration 87600, log loss is 0.1150, accuracy is 0.972
# iteration 87800, log loss is 0.1149, accuracy is 0.972
# iteration 88000, log loss is 0.1149, accuracy is 0.972
# iteration 88200, log loss is 0.1148, accuracy is 0.972
# iteration 88400, log loss is 0.1147, accuracy is 0.972
# iteration 88600, log loss is 0.1146, accuracy is 0.972
# iteration 88800, log loss is 0.1145, accuracy is 0.972
# iteration 89000, log loss is 0.1145, accuracy is 0.972
# iteration 89200, log loss is 0.1144, accuracy is 0.972
# iteration 89400, log loss is 0.1143, accuracy is 0.972
# iteration 89600, log loss is 0.1142, accuracy is 0.972
# iteration 89800, log loss is 0.1142, accuracy is 0.972
# iteration 90000, log loss is 0.1141, accuracy is 0.972
# iteration 90200, log loss is 0.1140, accuracy is 0.972
# iteration 90400, log loss is 0.1139, accuracy is 0.972
# iteration 90600, log loss is 0.1138, accuracy is 0.972
# iteration 90800, log loss is 0.1138, accuracy is 0.972
# iteration 91000, log loss is 0.1137, accuracy is 0.972
# iteration 91200, log loss is 0.1136, accuracy is 0.972
# iteration 91400, log loss is 0.1135, accuracy is 0.972
# iteration 91600, log loss is 0.1135, accuracy is 0.972
# iteration 91800, log loss is 0.1134, accuracy is 0.972
# iteration 92000, log loss is 0.1133, accuracy is 0.972
# iteration 92200, log loss is 0.1133, accuracy is 0.972
# iteration 92400, log loss is 0.1132, accuracy is 0.972
# iteration 92600, log loss is 0.1131, accuracy is 0.972
# iteration 92800, log loss is 0.1130, accuracy is 0.972
# iteration 93000, log loss is 0.1130, accuracy is 0.972
# iteration 93200, log loss is 0.1129, accuracy is 0.972
# iteration 93400, log loss is 0.1128, accuracy is 0.972
# iteration 93600, log loss is 0.1127, accuracy is 0.972
# iteration 93800, log loss is 0.1127, accuracy is 0.972
# iteration 94000, log loss is 0.1126, accuracy is 0.972
# iteration 94200, log loss is 0.1125, accuracy is 0.972
# iteration 94400, log loss is 0.1125, accuracy is 0.972
# iteration 94600, log loss is 0.1124, accuracy is 0.972
# iteration 94800, log loss is 0.1123, accuracy is 0.972
# iteration 95000, log loss is 0.1122, accuracy is 0.972
# iteration 95200, log loss is 0.1122, accuracy is 0.972
# iteration 95400, log loss is 0.1121, accuracy is 0.972
# iteration 95600, log loss is 0.1120, accuracy is 0.972
# iteration 95800, log loss is 0.1120, accuracy is 0.972
# iteration 96000, log loss is 0.1119, accuracy is 0.972
# iteration 96200, log loss is 0.1118, accuracy is 0.972
# iteration 96400, log loss is 0.1118, accuracy is 0.972
# iteration 96600, log loss is 0.1117, accuracy is 0.972
# iteration 96800, log loss is 0.1116, accuracy is 0.972
# iteration 97000, log loss is 0.1115, accuracy is 0.972
# iteration 97200, log loss is 0.1115, accuracy is 0.972
# iteration 97400, log loss is 0.1114, accuracy is 0.972
# iteration 97600, log loss is 0.1113, accuracy is 0.972
# iteration 97800, log loss is 0.1113, accuracy is 0.972
# iteration 98000, log loss is 0.1112, accuracy is 0.972
# iteration 98200, log loss is 0.1111, accuracy is 0.972
# iteration 98400, log loss is 0.1111, accuracy is 0.972
# iteration 98600, log loss is 0.1110, accuracy is 0.972
# iteration 98800, log loss is 0.1109, accuracy is 0.972
# iteration 99000, log loss is 0.1109, accuracy is 0.972
# iteration 99200, log loss is 0.1108, accuracy is 0.972
# iteration 99400, log loss is 0.1107, accuracy is 0.972
# iteration 99600, log loss is 0.1107, accuracy is 0.972
# iteration 99800, log loss is 0.1106, accuracy is 0.972

# %% [markdown]
# Plot the predicted answers, with mistakes in yellow

# %%
pred1 = (y_pred>=.5)
pred0 = (y_pred<.5)

fig, ax = plt.subplots(figsize=(8, 8))
# true predictions
ax.plot(x_mat[pred1 & (y==1),0],x_mat[pred1 & (y==1),1], 'ro', label='true positives')
ax.plot(x_mat[pred0 & (y==0),0],x_mat[pred0 & (y==0),1], 'bx', label='true negatives')
# false predictions
ax.plot(x_mat[pred1 & (y==0),0],x_mat[pred1 & (y==0),1], 'yx', label='false positives', markersize=15)
ax.plot(x_mat[pred0 & (y==1),0],x_mat[pred0 & (y==1),1], 'yo', label='false negatives', markersize=15, alpha=.6)
ax.set(title='Truth vs Prediction')
ax.legend(bbox_to_anchor=(1, 0.8), fancybox=True, shadow=True, fontsize='x-large');

# %% [markdown]
# ---
# ### Machine Learning Foundation (C) 2020 IBM Corporation

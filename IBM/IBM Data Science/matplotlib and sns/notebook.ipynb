# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %% [markdown]
# # Sigmoid Logistic Regression Function

# %%
x = np.arange(-6.0,7.0,1.0)
y = 1.0 / (1.0 + np.exp(-x))
plt.plot(x,y)
plt.show()
